# %%
import pandas as pd

df = pd.read_csv("./result/transformer_SupConWithTanimotoLoss_Augmentation_params.tsv", sep="\t")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

sns.set_style("whitegrid")
sns.set_palette("tab10")

fm.fontManager.addfont('/usr/share/fonts/truetype/msttcorefonts/times.ttf')
plt.rcParams['font.family'] = 'Times New Roman'

figure, ax = plt.subplots(1, 1, dpi=300, figsize=(5, 2.7))
ax.set_xlabel("Trials")
ax.set_ylabel("Hit@top1")
sns.scatterplot(x=df["number"].values + 1, y=df["value"].values, s=10)
ax.legend().remove()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hyperparameter_importances = {
    "Temperature": 0.8294,
    # "Heads": 0.00340,
    # "Alpha": 0.0019,
    "Layers": 0.0092,
    # "Base T": 0.00150,
    "Activation": 0.0827,
    "Batch Size": 0.0123,
    # "Lr": 0.0022,
    "Weight Decay": 0.0061,
    # "Target Dimension": 0.0023,
    "Epochs": 0.0182
}

figure, ax = plt.subplots(1, 1, dpi=300, figsize=(5, 2.7))
ax.set_xlabel("Importances")
ax.set_ylabel("Hyperparameters")

sns.barplot(hyperparameter_importances, orient="y")
# Out:
# <Axes: xlabel='Importances', ylabel='Hyperparameters'>
